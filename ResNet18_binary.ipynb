# %%
# %matplotlib inline

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'dataset_two_class'
#data_dir = 'dataset_three_class'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Visualize a few images
# ^^^^^^^^^^^^^^^^^^^^^^
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
train_accuracy = []
val_accuracy = []
train_loss = []
val_loss = []
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            if phase == 'train':
                train_accuracy.append(epoch_acc)
                train_loss.append(epoch_loss)
            else:
                val_accuracy.append(epoch_acc)
                val_loss.append(epoch_loss)
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# Visualizing the model predictions
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# Finetuning the convnet
# ----------------------
#
# Load a pretrained model and reset final fully connected layer.

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs,2)
#model_ft.fc = nn.Linear(num_ftrs,3) use this line instead of above one if classify three class 
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
train_accuracy = []
val_accuracy = []
train_loss = []
val_loss = []
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=50)
# Out:
# Epoch 0/49
# ----------
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:100: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule.See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# train Loss: 0.5791 Acc: 0.7499
# val Loss: 0.3944 Acc: 0.8362
#
# Epoch 1/49
# ----------
# train Loss: 0.5320 Acc: 0.7896
# val Loss: 0.1704 Acc: 0.9433
#
# Epoch 2/49
# ----------
# train Loss: 0.5678 Acc: 0.7947
# val Loss: 0.1594 Acc: 0.9433
#
# Epoch 3/49
# ----------
# train Loss: 0.5020 Acc: 0.8045
# val Loss: 0.1401 Acc: 0.9480
#
# Epoch 4/49
# ----------
# train Loss: 0.4515 Acc: 0.8292
# val Loss: 0.1510 Acc: 0.9528
#
# Epoch 5/49
# ----------
# train Loss: 0.4306 Acc: 0.8457
# val Loss: 0.4098 Acc: 0.8787
#
# Epoch 6/49
# ----------
# train Loss: 0.3239 Acc: 0.8795
# val Loss: 0.1258 Acc: 0.9528
#
# Epoch 7/49
# ----------
# train Loss: 0.3019 Acc: 0.8818
# val Loss: 0.1369 Acc: 0.9496
#
# Epoch 8/49
# ----------
# train Loss: 0.2991 Acc: 0.8795
# val Loss: 0.1347 Acc: 0.9512
#
# Epoch 9/49
# ----------
# train Loss: 0.2842 Acc: 0.8905
# val Loss: 0.1139 Acc: 0.9591
#
# Epoch 10/49
# ----------
# train Loss: 0.2974 Acc: 0.8799
# val Loss: 0.1283 Acc: 0.9496
#
# Epoch 11/49
# ----------
# train Loss: 0.2628 Acc: 0.8983
# val Loss: 0.1135 Acc: 0.9575
#
# Epoch 12/49
# ----------
# train Loss: 0.2715 Acc: 0.8963
# val Loss: 0.1097 Acc: 0.9591
#
# Epoch 13/49
# ----------
# train Loss: 0.2756 Acc: 0.8893
# val Loss: 0.1232 Acc: 0.9559
#
# Epoch 14/49
# ----------
# train Loss: 0.2702 Acc: 0.9026
# val Loss: 0.1200 Acc: 0.9559
#
# Epoch 15/49
# ----------
# train Loss: 0.2628 Acc: 0.8967
# val Loss: 0.1192 Acc: 0.9559
#
# Epoch 16/49
# ----------
# train Loss: 0.2671 Acc: 0.8924
# val Loss: 0.1071 Acc: 0.9543
#
# Epoch 17/49
# ----------
# train Loss: 0.2489 Acc: 0.9042
# val Loss: 0.1054 Acc: 0.9591
#
# Epoch 18/49
# ----------
# train Loss: 0.2672 Acc: 0.8948
# val Loss: 0.1123 Acc: 0.9591
#
# Epoch 19/49
# ----------
# train Loss: 0.2746 Acc: 0.8916
# val Loss: 0.1131 Acc: 0.9591
#
# Epoch 20/49
# ----------
# train Loss: 0.2626 Acc: 0.8920
# val Loss: 0.1193 Acc: 0.9559
#
# Epoch 21/49
# ----------
# train Loss: 0.2587 Acc: 0.9030
# val Loss: 0.1041 Acc: 0.9606
#
# Epoch 22/49
# ----------
# train Loss: 0.2676 Acc: 0.9003
# val Loss: 0.0963 Acc: 0.9622
#
# Epoch 23/49
# ----------
# train Loss: 0.2553 Acc: 0.8979
# val Loss: 0.0982 Acc: 0.9606
#
# Epoch 24/49
# ----------
# train Loss: 0.2555 Acc: 0.9011
# val Loss: 0.0974 Acc: 0.9638
#
# Epoch 25/49
# ----------
# train Loss: 0.2731 Acc: 0.8916
# val Loss: 0.1211 Acc: 0.9559
#
# Epoch 26/49
# ----------
# train Loss: 0.2647 Acc: 0.8975
# val Loss: 0.1220 Acc: 0.9575
#
# Epoch 27/49
# ----------
# train Loss: 0.2574 Acc: 0.9030
# val Loss: 0.1230 Acc: 0.9528
#
# Epoch 28/49
# ----------
# train Loss: 0.2726 Acc: 0.8936
# val Loss: 0.1046 Acc: 0.9622
#
# Epoch 29/49
# ----------
# train Loss: 0.2543 Acc: 0.8987
# val Loss: 0.1087 Acc: 0.9606
#
# Epoch 30/49
# ----------
# train Loss: 0.2639 Acc: 0.8983
# val Loss: 0.1278 Acc: 0.9528
#
# Epoch 31/49
# ----------
# train Loss: 0.2452 Acc: 0.9105
# val Loss: 0.1012 Acc: 0.9654
#
# Epoch 32/49
# ----------
# train Loss: 0.2679 Acc: 0.8877
# val Loss: 0.1099 Acc: 0.9606
#
# Epoch 33/49
# ----------
# train Loss: 0.2469 Acc: 0.9038
# val Loss: 0.0971 Acc: 0.9622
#
# Epoch 34/49
# ----------
# train Loss: 0.2741 Acc: 0.8924
# val Loss: 0.1092 Acc: 0.9606
#
# Epoch 35/49
# ----------
# train Loss: 0.2639 Acc: 0.8963
# val Loss: 0.1092 Acc: 0.9606
#
# Epoch 36/49
# ----------
# train Loss: 0.2513 Acc: 0.8952
# val Loss: 0.1037 Acc: 0.9575
#
# Epoch 37/49
# ----------
# train Loss: 0.2670 Acc: 0.8873
# val Loss: 0.1017 Acc: 0.9575
#
# Epoch 38/49
# ----------
# train Loss: 0.2483 Acc: 0.9054
# val Loss: 0.1173 Acc: 0.9606
#
# Epoch 39/49
# ----------
# train Loss: 0.2576 Acc: 0.9066
# val Loss: 0.1072 Acc: 0.9591
#
# Epoch 40/49
# ----------
# train Loss: 0.2426 Acc: 0.9046
# val Loss: 0.1108 Acc: 0.9591
#
# Epoch 41/49
# ----------
# train Loss: 0.2512 Acc: 0.9011
# val Loss: 0.1044 Acc: 0.9575
#
# Epoch 42/49
# ----------
# train Loss: 0.2643 Acc: 0.8975
# val Loss: 0.1028 Acc: 0.9591
#
# Epoch 43/49
# ----------
# train Loss: 0.2644 Acc: 0.9011
# val Loss: 0.1030 Acc: 0.9606
#
# Epoch 44/49
# ----------
# train Loss: 0.2569 Acc: 0.8956
# val Loss: 0.1070 Acc: 0.9575
#
# Epoch 45/49
# ----------
# train Loss: 0.2429 Acc: 0.9066
# val Loss: 0.1068 Acc: 0.9559
#
# Epoch 46/49
# ----------
# train Loss: 0.2446 Acc: 0.9026
# val Loss: 0.1018 Acc: 0.9622
#
# Epoch 47/49
# ----------
# train Loss: 0.2391 Acc: 0.9073
# val Loss: 0.1313 Acc: 0.9512
#
# Epoch 48/49
# ----------
# train Loss: 0.2459 Acc: 0.9015
# val Loss: 0.0972 Acc: 0.9638
#
# Epoch 49/49
# ----------
# train Loss: 0.2610 Acc: 0.8971
# val Loss: 0.1219 Acc: 0.9575
#
# Training complete in 20m 15s
# Best val Acc: 0.965354

# %%
visualize_model(model_ft)
plt.figure
plt.plot(range(len(train_accuracy)),train_accuracy)
plt.plot(range(len(val_accuracy)),val_accuracy)
plt.title('Two Class Chest X-ray Classification')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train_acc', 'val_acc'])
plt.show()
#Plot loss vs epoch
plt.figure
plt.plot(range(len(train_loss)),train_loss)
plt.plot(range(len(val_loss)),val_loss)
plt.title('Two Class Chest X-ray Classification')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train_loss', 'val_loss'])
plt.show()
